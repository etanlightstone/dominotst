# %%
# https://medium.com/@jebaseelanravi96/machine-learning-iris-classification-33aa18a4a983
# Get / work with the data
import numpy as np
import pandas as pd

input_file = "/mnt/data/iris/iris.csv"

iris_df = pd.read_csv(input_file, header = 0)
iris_df.head()
# Out:
#    Unnamed: 0  Unnamed: 0.1  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  \
# 0           0             0   1            5.1           3.5            1.4
# 1           1             1   2            4.9           3.0            1.4
# 2           2             2   3            4.7           3.2            1.3
# 3           3             3   4            4.6           3.1            1.5
# 4           4             4   5            5.0           3.6            1.4
#
#    PetalWidthCm      Species   color
# 0           0.2  Iris-setosa   green
# 1           0.2  Iris-setosa    pink
# 2           0.2  Iris-setosa  purple
# 3           0.2  Iris-setosa   green
# 4           0.2  Iris-setosa  orange

# %%
iris_df.isnull()
# Out:
#      Unnamed: 0  Unnamed: 0.1     Id  SepalLengthCm  SepalWidthCm  \
# 0         False         False  False          False         False
# 1         False         False  False          False         False
# 2         False         False  False          False         False
# 3         False         False  False          False         False
# 4         False         False  False          False         False
# ..          ...           ...    ...            ...           ...
# 145       False         False  False          False         False
# 146       False         False  False          False         False
# 147       False         False  False          False         False
# 148       False         False  False          False         False
# 149       False         False  False          False         False
#
#      PetalLengthCm  PetalWidthCm  Species  color
# 0            False         False    False  False
# 1            False         False    False  False
# 2            False         False    False  False
# 3            False         False    False  False
# 4            False         False    False  False
# ..             ...           ...      ...    ...
# 145          False         False    False  False
# 146          False         False    False  False
# 147          False         False    False  False
# 148          False         False    False  False
# 149          False         False    False  False
#
# [150 rows x 9 columns]

# %%
iris_df = pd.get_dummies(iris_df, columns=["color"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-35bfb8020a36> in <module>
#       1 iris_df = iris_df.dropna()
#       2
# ----> 3 iris_df[:,'color']
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3022             if self.columns.nlevels > 1:
#    3023                 return self._getitem_multilevel(key)
# -> 3024             indexer = self.columns.get_loc(key)
#    3025             if is_integer(indexer):
#    3026                 indexer = [indexer]
#
# /opt/conda/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3078             casted_key = self._maybe_cast_indexer(key)
#    3079             try:
# -> 3080                 return self._engine.get_loc(casted_key)
#    3081             except KeyError as err:
#    3082                 raise KeyError(key) from err
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 'color')' is an invalid key

# %%
# DATA PREP AND STORE DATASET

iris_df = iris_df.dropna()
#iris_df = pd.get_dummies(iris_df, columns=["color"])

iris_df.to_csv('iris_ads.csv')

# %%
# READ THE FINAL ADS

input_file = "iris_ads.csv"

iris_df = pd.read_csv(input_file, header = 0)
iris_df.head()
iris_df.shape
# Out:
# (150, 19)

# %%
# warning 'color' is a categorical calue

iris_dr = pd.read_csv(input_file, header = 0)

feature_cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm','color_green','color_pink','color_purple','color_orange','color_red','color_black','color_white']

x = iris_df.loc[:, feature_cols]
y = iris_df.Species


from sklearn.model_selection import GridSearchCV, train_test_split

# here we're splitting the data into train and test sets
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.5)

from sklearn import tree


classifier=tree.DecisionTreeClassifier()

# here we're training
classifier.fit(x_train,y_train)
predictions=classifier.predict(x_test)

# How did we do?
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,predictions))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-de34e17b0aec> in <module>
#       1 # warning 'color' is a categorical calue
#       2
# ----> 3 iris_dr = pd.read_csv(input_file, header = 0)
#       4
#       5 feature_cols = ['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm','PetalWidthCm','color_green','color_pink','color_purple','color_orange','color_red','color_black','color_white']
#
# NameError: name 'pd' is not defined

# %%
# FYI Here are the params you can tune for the DecisionTreeClassifier:
 param_dict = {
     "criterion":['gini','entropy'],
     "max_depth":range(1,10),
     "min_samples_split":range(2,10),
     "min_samples_leaf":range(1,5),
 }
